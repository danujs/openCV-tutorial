# %%
import sys

# %%
import cv2

# %%
import numpy as np

# %%
import cv2

# %%
cv2.__version__
# Out:
# '4.7.0'

# %%
cv2.__file__
# Out:
# 'c:\\users\\danu\\appdata\\local\\programs\\python\\python37\\lib\\site-packages\\cv2\\__init__.py'

# %%
img = cv2.imread("drone.jpg")

# %%
type(img)
# Out:
# numpy.ndarray

# %% [markdown]
# > Image Matrix

# %%
img.shape
# Out:
# (600, 900, 3)

# %%
type(img.shape)
# Out:
# tuple

# %%
#tuple unpacking
h, w, c =  img.shape

# %%
h, w, c
# Out:
# (600, 900, 3)

# %%
h * w
# Out:
# 540000

# %%
img.nbytes #in bytes
# Out:
# 1620000

# %%
img.nbytes/ 1024 #in kB
# Out:
# 1582.03125

# %%
import os

# %%
os.path.getsize("drone.jpg")/1024 #jpg compreseed file (in Kb)
# Out:
# 36.3271484375

# %%
img.ndim #3D
# Out:
# 3

# %%
img.min()
# Out:
# 0

# %%
img.max()
# Out:
# 255

# %%
img.size # n pixel
# Out:
# 1620000

# %%
h*w*c # n pixel
# Out:
# 1620000

# %% [markdown]
# > Access Image Channel

# %%
img[:, :, 0].shape # layer 0 (Blue)
# Out:
# (600, 900)

# %%
img[:,:,1].shape # layer 1 (green)
# Out:
# (600, 900)

# %%
img[:,:,2].shape # layer 2 (red)
# Out:
# (600, 900)

# %% [markdown]
# > Access Individual pixel

# %%
img[0,0]
# Out:
# array([239, 173, 125], dtype=uint8)

# %%
(B, G, R) = img[200,200]
print("R= %d, G= %d, B= %d" % (R, G, B)) #warna ini bisa di test di color picker
# Out:
# R= 189, G= 216, B= 246

# %% [markdown]
# > Read & Display Image

# %%
import cv2

# %%
# read image
img =  cv2.imread('drone.jpg')

# %% [markdown]
# > Using GUI OpenCV

# %%
#show image
cv2.imshow('drone.jpg',img)
cv2.waitKey(0) #display the window infinitely until any button is click
# cv2.destroyAllWindows() #click salah satu key di keyboard

# %%
cv2.destroyAllWindows()

# %%
import numpy as np

# %%
import cv2

# %%
img = cv2.imread("drone.jpg")

# %%
img =  cv2.imread('drone.jpg')
cv2.imshow('drone.jpg',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.destroyAllWindows()

# %%
chr(97)
# Out:
# 'a'

# %%
cv2.imshow('drone.jpg', img)
res = cv2.waitKey(4000)
print(res)
cv2.destroyAllWindows()
# Out:
# -1

# %%
cv2.imshow('drone.jpg', img)
res = cv2.waitKey(4000)
print("You pressed : %s" % chr (res)  if res >=0 and res <= 127 else "<unknown>")
cv2.destroyAllWindows()
# Out:
# <unknown>

# %% [markdown]
# > Using Matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.imshow(img)

# %%
img_rgb = img[:,:,::-1] # numpy reverse matrix (BGR to RGB)
plt.imshow(img_rgb)

# %%
img_red = img[:,:,2] #ambil layer merah
plt.imshow(img_red, cmap= 'gray') # ambil layer gray

# %%
img_green= img[:,:,1] #ambil layer green
plt.imshow(img_green, cmap= 'gray') # ambil layer gray

# %%
img_blue= img[:,:,0] #ambil layer blue
plt.imshow(img_blue, cmap= 'gray') # ambil layer gray

# %% [markdown]
# > Numpy Slicing [start:stop:step]

# %%
import numpy as np

# %%
a = np.arange(5)

# %%
a
# Out:
# array([0, 1, 2, 3, 4])

# %%
a[0:5]
# Out:
# array([0, 1, 2, 3, 4])

# %%
a[0:5:2]
# Out:
# array([0, 2, 4])

# %% [markdown]
# > Numpy Slicing Notation

# %% [markdown]
# a[start:]
#
# a[:stop]
#
# a[start:stop]
#
# a[start:stop:step]
#
# * Negative step (reverse array)
#
# a[::-1] #all items in the array, reversed
#
# a[1::-1] #the first two items, reversed
#
# a[:-3:-1]#the last two items, reversed
#
# a[-3::-1]#everything except the last two items, reversed
#
# * jika step bernilai negatif, start > stop

# %%
s = np.arange(7)

# %%
s
# Out:
# array([0, 1, 2, 3, 4, 5, 6])

# %%
s[1::-1]
# Out:
# array([1, 0])

# %%
s[:-3:-1]
# Out:
# array([6, 5])

# %%
s[-3::-1]
# Out:
# array([4, 3, 2, 1, 0])

# %%
s[-4::-1]
# Out:
# array([3, 2, 1, 0])

# %%
s[:-4:-1]
# Out:
# array([6, 5, 4])

# %% [markdown]
# > Convert menggunakan cv2.cvtColor

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) # conver BGR to RGB color
plt.imshow(img_rgb)

# %%
# task 2 GUI image using OpenCV GUI

# %%
import cv2

# %%
img1 = cv2.imread('drone.jpg')
img2 = cv2.imread('car.jpg')
cv2.imshow('myapp 1',img1)
cv2.imshow('myapp 2', img2)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# > Save image

# %%
# show image
cv2.imwrite('saved_drone.jpg', img)

# %% [markdown]
# > Play Video

# %%
# load video
cap = cv2.VideoCapture('webot.mp4')

# iterate for each frame in video

while cap.isOpened():
    
    # get image on each frame
    ret, frame = cap.read()
    if ret == True:
        
        # show image
        cv2.imshow('frame', frame)
    
        # wait 24ms per frame and close using 'q'
        if cv2.waitKey(24) == ord('q'):
            break
        if cv2.waitKey(24) == ord('s'):
            cv2.imwrite("fotofromvideo.jpg", frame)
            print("foto captured!")
    else:
        break
        
#close video
cap.release()
#close window
cv2.destroyAllWindows()

# %% [markdown]
# > Capture Photo

# %%
cap = cv2.VideoCapture(0) #indeks 0 utk camera laptop, indeks 1 utk camera webcam
ret, frame = cap.read()

if ret :
    cv2.imwrite("myphoto.jpg", frame)
else :
    print("can't save photo")
          
#close video
cap.release()

# %% [markdown]
# > Capture Video

# %%
import cv2

# %%
import cv2

# %%
import numpy as np
import cv2

cap = cv2.VideoCapture(0)

cap.set(cv2.CAP_PROP_FRAME_WIDTH, 320)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 240)


# Define the codec and create VideoWriter object
# fourcc is a 4-byte code used to specify the video codec
fourcc = cv2.VideoWriter_fourcc(*'MP4V') #fourcc for .avi
# out = cv2.VideoWriter('outpuet.mp4', fourcc, 30, (320, 240)) # name, fourcc, fps, size
out = cv2.VideoWriter("outvid.mp4", cv2.VideoWriter_fourcc('M','J','P','G'), 20.0, (640,480))
cv2.VideoWriter
while(cap.isOpened()):
    ret, frame = cap.read()
    if ret==True:
        frame = cv2.flip(frame,0)
        
        #write the flipped frame

        out.write(frame)
        
        cv2.imshow('frame', frame)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
        # if cv2.waitKey(20) == ord('s'):
        #     cv2.imwrite("fotoofvideo.jpg", frame)
        #     print("foto captured!")
    else:
        break
        
# release everything if job is finished
cap.release()
out.release()
cv2.destroyAllWindows()
